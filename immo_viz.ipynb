# %%
import pandas as pd
import numpy as np

# %%
immo_df = pd.read_csv("agence_immo_cleaned.csv", sep=',', encoding = "utf-8")
immo_df.head()
# Out:
#     price  bedrooms   longitude                      link   latitude    sqft  \
# 0   950.0       1.0 -122.396965  /sfc/apa/4076905111.html  37.761216     NaN
# 1   950.0       1.0 -122.396793  /sfc/apa/4076901755.html  37.761080     NaN
# 2   950.0       1.0 -122.397100  /sfc/apa/4076899340.html  37.762100     NaN
# 3  3300.0       1.0 -122.399747  /sfc/apa/4067393707.html  37.798108   830.0
# 4  2000.0       3.0         NaN  /sfc/apa/4076901071.html        NaN  1280.0
#
#                    city        date  id_proprio
# 0                 Paris  2022-01-01           1
# 1                  Lyon  2022-01-02           2
# 2                Annecy  2022-06-09           3
# 3  Boulogne-Billancourt  2022-05-14           4
# 4       Aix-en-Provence  2022-09-15           5

# %% [markdown]
# # Importation des bibliothèques pour la visualisation:
# Seaborn et Matplotlib qui sont des bibliothèques permettant de créer des graphiques statistiques

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(55,55)}, font_scale=1.6, style='whitegrid') 
tips = sns.load_dataset("tips") 
sns.boxplot(x=immo_df['city'], y=immo_df['price'])
# Out:
# <AxesSubplot:xlabel='city', ylabel='price'>

# %%
values=['Paris']
filtered_df = immo_df[immo_df.city.isin(values)]
print(filtered_df)
# Out:
#         price  bedrooms   longitude                      link   latitude  \
# 0       950.0       1.0 -122.396965  /sfc/apa/4076905111.html  37.761216
# 19     6495.0       3.0 -122.435472  /sfc/apa/4050192349.html  37.765727
# 38    11495.0       3.0         NaN  /sfc/apa/4072013382.html        NaN
# 57     5200.0       3.0 -122.456145  /sfc/apa/4068140340.html  37.722762
# 76     2600.0       1.0 -122.417487  /sfc/apa/4033313840.html  37.765183
# ...       ...       ...         ...                       ...        ...
# 4921   4350.0       2.0         NaN  /pen/apa/4072625855.html        NaN
# 4940   2600.0       2.0 -122.403594  /pen/apa/4073245119.html  37.683024
# 4959   2960.0       2.0 -122.261374  /pen/apa/4072085764.html  37.534539
# 4978   3200.0       2.0 -122.209100  /pen/apa/4072514779.html  37.481500
# 4997   4000.0       2.0 -122.274837  /pen/apa/4072004661.html  37.454546
#
#         sqft   city        date  id_proprio
# 0        NaN  Paris  2022-01-01           1
# ...

# %%
sns.boxplot(x=filtered_df['city'], y=filtered_df['price'])
# Out:
# <AxesSubplot:xlabel='city', ylabel='price'>
